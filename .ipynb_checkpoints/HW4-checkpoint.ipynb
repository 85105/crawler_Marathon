# %%
import requests
import json
r = requests.get('https://www.ris.gov.tw/rs-opendata/api/Main/docs/v1')
r.text
json.loads(r.text)
# Out:
# {'swagger': '2.0',
#  'info': {'title': '中華民國內政部戶政司OPEN API',
#   'version': '1.0.0',
#   'contact': {'name': '中華民國內政部戶政司', 'url': 'https://www.ris.gov.tw'},
#   'description': '戶役政資訊系統統計資料集<div>最後更新時間:109年06月24日 12:01:08</div>'},
#  'externalDocs': {'url': 'https://www.ris.gov.tw/rs-opendata/api/Main/docs/v1'},
#  'schemes': ['https'],
#  'consumes': ['application/json'],
#  'produces': ['application/json; charset=utf-8'],
#  'security': [],
#  'host': 'www.ris.gov.tw',
#  'basePath': '/rs-opendata/api/v1/datastore',
#  'tags': [{'name': 'ODRP001', 'description': '各村（里）戶籍人口統計月報表'},
#   {'name': 'ODRP002', 'description': '遷入遷出統計表'},
#   {'name': 'ODRP003', 'description': '動態資料統計表'},
#   {'name': 'ODRP004', 'description': '現住人口數按性別及原住民身分分'},
#   {'name': 'ODRP005', 'description': '村里戶數、單一年齡人口'},
#   {'name': 'ODRP006', 'description': '現住原住民人口按性別、年齡'},
#   {'name': 'ODRP007', 'description': '結婚人數按結婚者雙方原屬國籍（地區）分'},
#   {'name': 'ODRP008', 'description': '離婚人數按離婚者雙方原屬國籍（地區）分'},
# ...
