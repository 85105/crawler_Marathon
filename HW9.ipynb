# %%
import requests
import os
from bs4 import BeautifulSoup
from PIL import Image
from fake_useragent import UserAgent

# %%
url = "https://www.ptt.cc/bbs/Beauty/M.1578626247.A.30A.html"
ua = UserAgent()
header = {'User-agent' : ua.random, 'cookie' : 'over18=1'}
#header = {'User-agent' : ua.random}
resp = requests.get(url, headers = header)
soup = BeautifulSoup(resp.text,"lxml")
print(soup)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>[正妹] 新垣結衣 - 看板 Beauty - 批踢踢實業坊</title>
# <meta content="all" name="robots"/>
# <meta content="Ptt BBS 批踢踢" name="keywords"/>
# <meta content="https://imgur.com/kGQ5rrW.jpg
# https://imgur.com/LtJ4nB9.jpg
# https://imgur.com/pWpU577.jpg
# https://imgur.com/K7rM2Ik.jpg
# https://imgur.com/dnUQt0Z.jpg
# " name="description"/>
# <meta content="Ptt 批踢踢實業坊" property="og:site_name"/>
# <meta content="[正妹] 新垣結衣" property="og:title"/>
# <meta content="https://imgur.com/kGQ5rrW.jpg
# https://imgur.com/LtJ4nB9.jpg
# https://imgur.com/pWpU577.jpg
# https://imgur.com/K7rM2Ik.jpg
# https://imgur.com/dnUQt0Z.jpg
# " property="og:description"/>
# <link href="https://www.ptt.cc/bbs/Beauty/M.1578626247.A.30A.html" rel="canonical"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# ...

# %%
output_dir = 'download'
#定位
image_tags = soup.find(id='main-content').findChildren('a', recursive=False)
for img_tag in image_tags:
    img_id = img_tag['href'].split('/')[-1]
    print(img_id)
    img_url = 'https://imgur.com/{}'.format(img_id)
    print(img_url)
    #對每一張下載
    with requests.get(img_url, stream=True) as r:
        #檢查狀態碼
        print(r.raise_for_status())
        #原始socket
        img = Image.open(r.raw)
        print(img)
        img_savename = '{outdir}/{img_id}.{img_ext}'.format(outdir=output_dir, img_id=img_id, img_ext=img.format.lower())
        print(mg_savename)
        img.save(img_savename)
        print('Save image {}'.format(img_savename))
# Out:
# kGQ5rrW.jpg
# https://imgur.com/kGQ5rrW.jpg
# None
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x1346 at 0x1F2FFEFAE08>
# download/kGQ5rrW.jpg.jpeg
# Save image download/kGQ5rrW.jpg.jpeg
# LtJ4nB9.jpg
# https://imgur.com/LtJ4nB9.jpg
# None
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=240x320 at 0x1F2FF154808>
# download/kGQ5rrW.jpg.jpeg
# Save image download/LtJ4nB9.jpg.jpeg
# pWpU577.jpg
# https://imgur.com/pWpU577.jpg
# None
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=543x665 at 0x1F281036288>
# download/kGQ5rrW.jpg.jpeg
# Save image download/pWpU577.jpg.jpeg
# K7rM2Ik.jpg
# https://imgur.com/K7rM2Ik.jpg
# None
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x653 at 0x1F281028488>
# download/kGQ5rrW.jpg.jpeg
# Save image download/K7rM2Ik.jpg.jpeg
# dnUQt0Z.jpg
# https://imgur.com/dnUQt0Z.jpg
# None
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=580x327 at 0x1F2FFF0C508>
# download/kGQ5rrW.jpg.jpeg
# ...

# %%
print(img.format)
# Out:
# GIF

# %% [markdown]
# # HW
# #### 以正確的副檔名下載網頁中的圖片

# %%
import requests
from bs4 import BeautifulSoup
import os
from PIL import Image
from fake_useragent import UserAgent

# %%
url = "https://www.ptt.cc/bbs/Beauty/M.1556291059.A.75A.html"
user_agent = UserAgent().random
header = {"User-agent":user_agent,"cookie":"over18=1"}
res = requests.get(url,headers=header)
soup = BeautifulSoup(res.text,"lxml")
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>[正妹] 新垣結衣幾張 發錢 - 看板 Beauty - 批踢踢實業坊</title>
# <meta content="all" name="robots"/>
# <meta content="Ptt BBS 批踢踢" name="keywords"/>
# <meta content="看了上面那篇又開始打開資料夾複習國民老婆的照片
# 又再次戀愛了 希望各位不要和我搶老婆&gt;///&lt;
# 結衣是我的
# https://imgur.com/Cgb5oo1
# https://imgur.com/MgjHY4f
# " name="description"/>
# <meta content="Ptt 批踢踢實業坊" property="og:site_name"/>
# <meta content="[正妹] 新垣結衣幾張 發錢" property="og:title"/>
# <meta content="看了上面那篇又開始打開資料夾複習國民老婆的照片
# 又再次戀愛了 希望各位不要和我搶老婆&gt;///&lt;
# 結衣是我的
# https://imgur.com/Cgb5oo1
# https://imgur.com/MgjHY4f
# " property="og:description"/>
# <link href="https://www.ptt.cc/bbs/Beauty/M.1556291059.A.75A.html" rel="canonical"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# ...

# %%
output_dir = 'download'
image_tags = soup.find(id='main-content').findChildren('a', recursive=False)
for i in image_tags:
    img_id = i['href'].split('/')[-1]
    print(img_id)
    url = 'https://imgur.com/{}.jpg'.format(img_id)
    print(url)
    with requests.get(url, stream=True) as r:
        print(r.raise_for_status())
        img = Image.open(r.raw)
        save = "{dirr}/{idd}.{extension}".format(dirr=output_dir,idd=img_id,extension=img.format.lower())
        img.save(save)
# Out:
# Cgb5oo1
# https://imgur.com/Cgb5oo1.jpg
# None
# MgjHY4f
# https://imgur.com/MgjHY4f.jpg
# None
# yeoRtAs
# https://imgur.com/yeoRtAs.jpg
# None
# wsauNEW
# https://imgur.com/wsauNEW.jpg
# None
# IjiETcs
# https://imgur.com/IjiETcs.jpg
# None
